# %% [markdown]
# # Transfer learning
#
# You can find an example of transfer learning on [PyTorch's homepage](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html). Here, we will use the same data set and architecture to make a comparison to the PyTorch homepage easier.
#
# <!--
# - [Training data](#Training-data)
# - [Validation data](#Validation-data)
# - [Finetuning an existing CNN](#Finetuning-an-existing-CNN)
# - [Feature extraction](#Feature-extraction)
# - [Exercises](#Exercises)
# -->

# %%
# PyTorch
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
# Pretrained networks
from torchvision.models import resnet50, resnet18
# Other packages
import matplotlib.pyplot as plt
import numpy as np
import time

# %% [markdown]
# ## Training data

# %% [markdown]
# As always, we start by loading the data. Unlike the CIFAR10 dataset in notebook 2.1, there is no direct command for uploading the data, but the data is still directly available on PyTorch's homepage.

# %%
# !wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
# !unzip -o -q hymenoptera_data.zip
# Out:
# --2024-11-22 09:00:07--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 3.165.102.113, 3.165.102.31, 3.165.102.62, ...
# Connecting to download.pytorch.org (download.pytorch.org)|3.165.102.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip.1’
#
# hymenoptera_data.zi 100%[===================>]  45.10M   284MB/s    in 0.2s
#
# 2024-11-22 09:00:08 (284 MB/s) - ‘hymenoptera_data.zip.1’ saved [47286322/47286322]

# %% [markdown]
# Before loading the dataset into objects in Python, let's define the necessary transformations. We want to perform learning and thus need to get the images into the right format: the used neural networks expect the images to be 224x224 pixels. We also normalise the images. As we will see below, the data set is rather small. To deal with this, we add data augmentation (random rotation, random horizontal flip, random vertical flip, random resizing and random crop discussed in notebook 1.2). Data augmentation will not be needed for the test set. We will address this in the exercises.

# %%
means = np.array([0.485, 0.456, 0.406])
stds = np.array([0.229, 0.224, 0.225])

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224), # Randomly resize and to the model's expected input size
    transforms.RandomHorizontalFlip(), # Other augmentation
    transforms.ToTensor(),  # convert to PyTorch tensor
    transforms.Normalize(mean=means, std=stds)  # normalize images
])

# %%
# Load the Hymenoptera dataset
trainset = ImageFolder(root='hymenoptera_data/train', transform=train_transform)

trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
class_names = trainset.classes

# %% [markdown]
# Let's have a rudimentary look at the data.

# %%
print(class_names)
# Out:
# ['ants', 'bees']

# %%
# Iterate over the DataLoader to get a batch of data
for batch in trainloader:
    images, labels = batch
    break  # Break after the first batch to get the first image

# Plot the first image
# Note that we multiply by stds and add means when taking data from Dataloader, since Dataload
# will apply all our transformations including the normalisation
image = torchvision.utils.make_grid(images[0]).numpy().transpose((1, 2, 0))*stds+means
plt.imshow(image)
plt.title(f"Label: {labels[0]}")
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
trainset_size = len(trainset)
print(trainset_size)
# Out:
# 244

# %% [markdown]
# There are only 244 images in the training set. That's too few to train your own neural network robustly from scratch. Rather than following the setup in notebook 2.1, we thus instantiate a pre-trained model.

# %% [markdown]
# ## Validation data
#
# In addition to the training data, we need data for different testing. More specifically, we need a data set for testing *during training*, i.e. a data set that the model doesn't use for training but that is used to evaluate the performance of the model at each new epoch. This type of testing is called validation. The validation data will not be augmented, and hence, we need another transform: during the validation phase, the primary concern is to evaluate the model's performance based on data that you would encounter in real-world scenarios.

# %%
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(means, stds)
])

# %%
valset = ImageFolder(root='hymenoptera_data/val', transform=val_transform)
valloader = DataLoader(valset, batch_size=32, shuffle=True)

# %%
valset_size = len(valset)
print(valset_size)
# Out:
# 153

# %% [markdown]
# ## Finetuning an existing CNN
#
# Let's fetch a pre-trained network.

# %%
# Instigate the pretrained model
model1 = resnet50(pretrained=True)

# First, we need to know how many input features the last layer of the original model has
n_ftrs = model1.fc.in_features

# Then, we want to replace the last layer with a new outputlayer that matches the dataset.
n_classes = len(class_names)
model1.fc = nn.Linear(n_ftrs, n_classes)

# %% [markdown]
# That's it, really: you have now defined your network. All you have to do now is to finetune your network to the new data set by adjusting the parameters through training on the data set. To do this, you would follow (more or less) the same steps as in notebook 2.1, i.e. the code from this point on would look just as if you had made your own network from scratch. We will address this in the exercises.

# %% [markdown]
# ## Feature extraction
#
# Instead of finetuning the parameters of the entire network, you could limit yourself to calibrating the final layer, i.e. the addition to the network. To do this, you need to "freeze" the rest of the network.

# %%
model2 = torchvision.models.resnet18(pretrained=True) # You could also use resnet50 as above
# Freeze the network
for param in model2.parameters():
    param.requires_grad = False

n_ftrs = model2.fc.in_features
n_classes = len(class_names)
model2.fc = nn.Linear(n_ftrs, n_classes)

# %% [markdown]
# Again, that's really all there is to it. Now, you have a new model. You just need to train it...

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1**: Finish the code below in order to write a function for training your network. As you can see, we have added a few extra lines of code compared to the code in notebook 2.1 (e.g., on validation). Explain this code.

# %%
def train_model(model, loss_func, optimizer, scheduler, num_epochs=25):

    train_losses = []
    val_losses = []
    start = time.time()
    model.train()

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        model.train()  # Set model to training mode

        training_loss = 0.0
        val_loss = 0.0

        # Iterate over data.
        for inputs, labels in trainloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            y_pred = model(inputs)

            # Compute loss
            loss = loss_func(y_pred, labels)

            # Backward pass
            loss.backward()

            # Optimise
            optimizer.step()

            # Update the learning rate using the scheduler
            scheduler.step()

            # statistics
            training_loss += loss.item() * inputs.size(0)

        epoch_train_loss = training_loss / trainset_size
        train_losses.extend([epoch_train_loss])

        # Now, we continue to validation
        model.eval()   # Set model to evaluate mode
        for inputs, labels in valloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            with torch.no_grad():  # Disable gradient computation
                y_pred = model(inputs)
                loss = loss_func(y_pred, labels)

            # Forward pass
            y_pred = model(inputs)

            # Compute loss
            loss = loss_func(y_pred, labels)

            # statistics
            val_loss += loss.item() * inputs.size(0)

        epoch_val_loss = val_loss / valset_size
        val_losses.extend([epoch_val_loss])

        print(f'Training loss: {epoch_train_loss:.4f}, validation loss: {epoch_val_loss:.4f}')

    time_end = time.time() - start
    print(f'Training completed in {time_end // 60:.0f}m {time_end % 60:.0f}s')

    return model, train_losses, val_losses

# %% [markdown]
# **Exercise 2**: In the function above, we added the line "scheduler.step()". What is that good for?
#
# To train your network, you need to define an optimiser and loss function. Let's start with model1.

# %%
optimizer1 = optim.Adam(model1.parameters(), lr=1e-3, weight_decay=1e-4)

loss_func1 = nn.CrossEntropyLoss()

# %% [markdown]
# And we have to define a scheduler (what is that?)

# %%
scheduler1 = lr_scheduler.StepLR(optimizer1, step_size=7, gamma=0.1)

# %% [markdown]
# You could check whether you have GPUs and then move the training there is possible.

# %%
# check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# move to GPU
model1 = model1.to(device)

# %% [markdown]
# Now, we can train by calling the function above. This might take some time, which is why we will limit ourselves to 5 epochs here. *You shouldn't do this if you want to train a proper neural network.* However, it's good enough for our purposes, and proper training might take many minutes or hours: here, we just want to illustrate and understand how neural networks work.

# %%
model1, train_loss1, val_loss1 = train_model(model1, loss_func1, optimizer1, scheduler1, num_epochs=10)

# Save the model
PATH = './model1_cnn.pth'
torch.save(model1.state_dict(), PATH)
# Out:
# Epoch 0/9
# Training loss: 0.8026, validation loss: 47.4275
# Epoch 1/9
# Training loss: 0.5470, validation loss: 1.2985
# Epoch 2/9
# Training loss: 0.3576, validation loss: 0.4730
# Epoch 3/9
# Training loss: 0.3521, validation loss: 0.4097
# Epoch 4/9
# Training loss: 0.3101, validation loss: 0.4121
# Epoch 5/9
# Training loss: 0.3337, validation loss: 0.4181
# Epoch 6/9
# Training loss: 0.2862, validation loss: 0.4105
# Epoch 7/9
# Training loss: 0.3191, validation loss: 0.4126
# Epoch 8/9
# Training loss: 0.3618, validation loss: 0.4170
# Epoch 9/9
# Training loss: 0.3634, validation loss: 0.4181
# Training completed in 0m 55s

# %% [markdown]
# **Exercise 3**: Plot the training and validation loss as a function of the epoch. Discuss the plot.

# %%
plt.figure(figsize=(8,8))
# Plot the training and validation loss
plt.plot(train_loss1, label="Training Loss", color='blue', linewidth=2)
plt.plot(val_loss1, label="Validation Loss", color='red', linestyle='--', linewidth=2)
plt.legend(fontsize=14)
plt.xlabel("Epochs",fontsize=14)
plt.ylabel("Loss",fontsize=14)
plt.ylim([0.25,1.5])
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Exercise 4**: Evaluate the accuracy of the convolutional neural network on the training and validation set. Since rerunning the training might take very long, you can just compute this measure for the final epoch, but how would you go about adding the corresponding lines of code to the training function and tracking it during training for each epoch?

# %%
# Evaluate accuracy on the training set (final epoch)
model1.eval()  # Set model to evaluation mode
train_correct = 0
train_total = 0

with torch.no_grad():  # Disable gradient computation
    for inputs, labels in trainloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        y_pred = model1(inputs)

        # Get predicted class
        _, predicted = torch.max(y_pred, 1)

        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

# Calculate final training accuracy
train_accuracy = train_correct / train_total
print(f"Final Epoch Training Accuracy: {train_accuracy:.4f}")

# Evaluate accuracy on the validation set (final epoch)
val_correct = 0
val_total = 0

with torch.no_grad():  # Disable gradient computation
    for inputs, labels in valloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        y_pred = model1(inputs)

        # Get predicted class
        _, predicted = torch.max(y_pred, 1)

        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

# Calculate final validation accuracy
val_accuracy = val_correct / val_total
print(f"Final Epoch Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Final Epoch Training Accuracy: 0.8730
# Final Epoch Validation Accuracy: 0.8235

# %% [markdown]
# **Exercise 5**: Train model2 (the convolutional neural network as fixed feature extractor). Hint: You can use the same training function as above, but you need to define an optimiser, a loss function, and a scheduler.

# %%
model2 = model2.to(device)

# Define the loss function
loss_func2 = nn.CrossEntropyLoss()

# Define the optimizer (only optimize the final layer's parameters)
optimizer2 = optim.SGD(model2.fc.parameters(), lr=0.005, momentum=0.9, weight_decay=1e-4)

# Define a learning rate scheduler (optional, but useful)
scheduler2 = lr_scheduler.StepLR(optimizer2, step_size=7, gamma=0.1)

# Now train the model using the train_model function
model2, train_loss2, val_loss2 = train_model(model2, loss_func2, optimizer2, scheduler2, num_epochs=15)
# Out:
# Epoch 0/14
# Training loss: 0.6728, validation loss: 0.7334
# Epoch 1/14
# Training loss: 0.5500, validation loss: 0.3233
# Epoch 2/14
# Training loss: 0.3583, validation loss: 0.3285
# Epoch 3/14
# Training loss: 0.3528, validation loss: 0.3330
# Epoch 4/14
# Training loss: 0.3590, validation loss: 0.3344
# Epoch 5/14
# Training loss: 0.3382, validation loss: 0.3355
# Epoch 6/14
# Training loss: 0.3373, validation loss: 0.3359
# Epoch 7/14
# Training loss: 0.3384, validation loss: 0.3362
# Epoch 8/14
# Training loss: 0.3505, validation loss: 0.3336
# Epoch 9/14
# Training loss: 0.3812, validation loss: 0.3362
# Epoch 10/14
# Training loss: 0.3485, validation loss: 0.3366
# Epoch 11/14
# Training loss: 0.3559, validation loss: 0.3346
# Epoch 12/14
# Training loss: 0.3408, validation loss: 0.3381
# Epoch 13/14
# Training loss: 0.3585, validation loss: 0.3377
# Epoch 14/14
# Training loss: 0.3539, validation loss: 0.3362
# Training completed in 0m 43s

# %%
plt.figure(figsize=(8,8))
# Plot the training and validation loss
plt.plot(train_loss2, label="Training Loss", color='blue', linewidth=2)
plt.plot(val_loss2, label="Validation Loss", color='red', linestyle='--', linewidth=2)
plt.legend(fontsize=14)
plt.xlabel("Epochs",fontsize=14)
plt.ylabel("Loss",fontsize=14)
plt.ylim([0.25,0.8])
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Exercise 6**: Go through the code in the example of [PyTorch's homepage](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html). Highlight differences between the code in the example and the code in this notebook. Discuss these differences in the group.
